# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiago150196/analise-vendas-negocio/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Análise das Emissões de Gases do Efeito Estufa no Brasil (1970–2021)

# %% [markdown]
# ### 🎯 Objetivo
# Analisar as emissões de gases do efeito estufa no Brasil para identificar padrões por setor, tipo de gás e evolução ao longo do tempo.

# %% [markdown]
# ## 🎯 Perguntas de negócio
#
# - Quais gases mais contribuem para as emissões no Brasil?
# - Quais setores são os maiores emissores?
# - Como as emissões evoluíram ao longo do tempo?
# - Existem setores que cresceram mais nos últimos anos?
# - Quais estados apresentam maiores níveis de emissão?

# %%
import pandas as pd

# %%
emissoes_gases = pd.read_excel ('/content/drive/MyDrive/1-SEEG10_GERAL-BR_UF_2022.10 (1).27-FINAL-SITE.xlsx' , sheet_name = 'GEE Estados')
# Out:
# /usr/local/lib/python3.12/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# Base de dados de emissões de gases do efeito estufa no Brasil
# Fonte: SEEG

# %%
print("Dimensão do dataset:", emissoes_gases.shape)
emissoes_gases.info()
emissoes_gases.head()
# Out:
# Dimensão do dataset: (103312, 63)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103312 entries, 0 to 103311
# Data columns (total 63 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Nível 1 - Setor             103312 non-null  object
#  1   Nível 2                     103312 non-null  object
#  2   Nível 3                     103253 non-null  object
#  3   Nível 4                     90920 non-null   object
#  4   Nível 5                     100788 non-null  object
#  5   Nível 6                     97691 non-null   object
#  6   Emissão / Remoção / Bunker  103312 non-null  object
#  7   Gás                         103312 non-null  object
#  8   Estado                      97374 non-null   object
#  9   Atividade Econômica         102076 non-null  object
#  10  Produto                     37413 non-null   object
#  11  1970                        103312 non-null  float64
#  12  1971                        103312 non-null  float64
#  13  1972                        103312 non-null  float64
#  14  1973                        103312 non-null  float64
#  15  1974                        103312 non-null  float64
#  16  1975                        103312 non-null  float64
#  17  1976                        103312 non-null  float64
#  18  1977                        103312 non-null  float64
#  19  1978                        103312 non-null  float64
#  20  1979                        103312 non-null  float64
#  21  1980                        103312 non-null  float64
#  22  1981                        103312 non-null  float64
#  23  1982                        103312 non-null  float64
#  24  1983                        103312 non-null  float64
#  25  1984                        103312 non-null  float64
#  26  1985                        103312 non-null  float64
#  27  1986                        103312 non-null  float64
#  28  1987                        103312 non-null  float64
#  29  1988                        103312 non-null  float64
#  30  1989                        103312 non-null  float64
#  31  1990                        103312 non-null  float64
#  32  1991                        103312 non-null  float64
#  33  1992                        103312 non-null  float64
#  34  1993                        103312 non-null  float64
#  35  1994                        103312 non-null  float64
#  36  1995                        103312 non-null  float64
#  37  1996                        103312 non-null  float64
#  38  1997                        103312 non-null  float64
#  39  1998                        103312 non-null  float64
#  40  1999                        103312 non-null  float64
#  41  2000                        103312 non-null  float64
#  42  2001                        103312 non-null  float64
#  43  2002                        103312 non-null  float64
#  44  2003                        103312 non-null  float64
#  45  2004                        103312 non-null  float64
#  46  2005                        103312 non-null  float64
#  47  2006                        103312 non-null  float64
#  48  2007                        103312 non-null  float64
#  49  2008                        103312 non-null  float64
#  50  2009                        103312 non-null  float64
#  51  2010                        103312 non-null  float64
#  52  2011                        103312 non-null  float64
#  53  2012                        103312 non-null  float64
#  54  2013                        103312 non-null  float64
#  55  2014                        103312 non-null  float64
#  56  2015                        103312 non-null  float64
#  57  2016                        103312 non-null  float64
#  58  2017                        103312 non-null  float64
#  59  2018                        103312 non-null  float64
#  60  2019                        103312 non-null  float64
#  61  2020                        103312 non-null  float64
#  62  2021                        103312 non-null  float64
# dtypes: float64(52), object(11)
# memory usage: 49.7+ MB
#          Nível 1 - Setor            Nível 2                    Nível 3  \
# 0  Processos Industriais  Indústria Química            Produção de ABS
# 1  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 2  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 3  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 4  Processos Industriais  Indústria Química  Produção de Ácido Adípico
#
#   Nível 4 Nível 5 Nível 6 Emissão / Remoção / Bunker               Gás Estado  \
# 0     NaN     NaN     NaN                    Emissão         COVNM (t)     SP
# 1     NaN     NaN     NaN                    Emissão           N2O (t)     SP
# 2     NaN     NaN     NaN                    Emissão            CO (t)     SP
# 3     NaN     NaN     NaN                    Emissão           NOx (t)     SP
# 4     NaN     NaN     NaN                    Emissão  CO2e (t) GWP-AR2     SP
#
#   Atividade Econômica  ...       2012       2013       2014       2015  \
# 0           OUTRA_IND  ...    897.600    897.600    897.600    897.600
# 1           OUTRA_IND  ...    130.000    130.000    130.000    130.000
# 2           OUTRA_IND  ...   1380.576   1380.576   1380.576   1380.576
# 3           OUTRA_IND  ...    431.430    431.430    431.430    431.430
# 4           OUTRA_IND  ...  40300.000  40300.000  40300.000  40300.000
#
#         2016       2017       2018       2019       2020       2021
# 0    897.600    897.600    897.600    897.600    897.600    897.600
# 1    130.000    130.000    130.000    130.000    130.000    130.000
# 2   1380.576   1380.576   1380.576   1380.576   1380.576   1380.576
# 3    431.430    431.430    431.430    431.430    431.430    431.430
# 4  40300.000  40300.000  40300.000  40300.000  40300.000  40300.000
#
# [5 rows x 63 columns]

# %%
# Dimensão do dataset
print("Dimensão:", emissoes_gases.shape)

# Estrutura dos dados
emissoes_gases.info()

# Primeiras linhas
emissoes_gases.head()
# Out:
# Dimensão: (103312, 63)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103312 entries, 0 to 103311
# Data columns (total 63 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Nível 1 - Setor             103312 non-null  object
#  1   Nível 2                     103312 non-null  object
#  2   Nível 3                     103253 non-null  object
#  3   Nível 4                     90920 non-null   object
#  4   Nível 5                     100788 non-null  object
#  5   Nível 6                     97691 non-null   object
#  6   Emissão / Remoção / Bunker  103312 non-null  object
#  7   Gás                         103312 non-null  object
#  8   Estado                      97374 non-null   object
#  9   Atividade Econômica         102076 non-null  object
#  10  Produto                     37413 non-null   object
#  11  1970                        103312 non-null  float64
#  12  1971                        103312 non-null  float64
#  13  1972                        103312 non-null  float64
#  14  1973                        103312 non-null  float64
#  15  1974                        103312 non-null  float64
#  16  1975                        103312 non-null  float64
#  17  1976                        103312 non-null  float64
#  18  1977                        103312 non-null  float64
#  19  1978                        103312 non-null  float64
#  20  1979                        103312 non-null  float64
#  21  1980                        103312 non-null  float64
#  22  1981                        103312 non-null  float64
#  23  1982                        103312 non-null  float64
#  24  1983                        103312 non-null  float64
#  25  1984                        103312 non-null  float64
#  26  1985                        103312 non-null  float64
#  27  1986                        103312 non-null  float64
#  28  1987                        103312 non-null  float64
#  29  1988                        103312 non-null  float64
#  30  1989                        103312 non-null  float64
#  31  1990                        103312 non-null  float64
#  32  1991                        103312 non-null  float64
#  33  1992                        103312 non-null  float64
#  34  1993                        103312 non-null  float64
#  35  1994                        103312 non-null  float64
#  36  1995                        103312 non-null  float64
#  37  1996                        103312 non-null  float64
#  38  1997                        103312 non-null  float64
#  39  1998                        103312 non-null  float64
#  40  1999                        103312 non-null  float64
#  41  2000                        103312 non-null  float64
#  42  2001                        103312 non-null  float64
#  43  2002                        103312 non-null  float64
#  44  2003                        103312 non-null  float64
#  45  2004                        103312 non-null  float64
#  46  2005                        103312 non-null  float64
#  47  2006                        103312 non-null  float64
#  48  2007                        103312 non-null  float64
#  49  2008                        103312 non-null  float64
#  50  2009                        103312 non-null  float64
#  51  2010                        103312 non-null  float64
#  52  2011                        103312 non-null  float64
#  53  2012                        103312 non-null  float64
#  54  2013                        103312 non-null  float64
#  55  2014                        103312 non-null  float64
#  56  2015                        103312 non-null  float64
#  57  2016                        103312 non-null  float64
#  58  2017                        103312 non-null  float64
#  59  2018                        103312 non-null  float64
#  60  2019                        103312 non-null  float64
#  61  2020                        103312 non-null  float64
#  62  2021                        103312 non-null  float64
# dtypes: float64(52), object(11)
# memory usage: 49.7+ MB
#          Nível 1 - Setor            Nível 2                    Nível 3  \
# 0  Processos Industriais  Indústria Química            Produção de ABS
# 1  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 2  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 3  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 4  Processos Industriais  Indústria Química  Produção de Ácido Adípico
#
#   Nível 4 Nível 5 Nível 6 Emissão / Remoção / Bunker               Gás Estado  \
# 0     NaN     NaN     NaN                    Emissão         COVNM (t)     SP
# 1     NaN     NaN     NaN                    Emissão           N2O (t)     SP
# 2     NaN     NaN     NaN                    Emissão            CO (t)     SP
# 3     NaN     NaN     NaN                    Emissão           NOx (t)     SP
# 4     NaN     NaN     NaN                    Emissão  CO2e (t) GWP-AR2     SP
#
#   Atividade Econômica  ...       2012       2013       2014       2015  \
# 0           OUTRA_IND  ...    897.600    897.600    897.600    897.600
# 1           OUTRA_IND  ...    130.000    130.000    130.000    130.000
# 2           OUTRA_IND  ...   1380.576   1380.576   1380.576   1380.576
# 3           OUTRA_IND  ...    431.430    431.430    431.430    431.430
# 4           OUTRA_IND  ...  40300.000  40300.000  40300.000  40300.000
#
#         2016       2017       2018       2019       2020       2021
# 0    897.600    897.600    897.600    897.600    897.600    897.600
# 1    130.000    130.000    130.000    130.000    130.000    130.000
# 2   1380.576   1380.576   1380.576   1380.576   1380.576   1380.576
# 3    431.430    431.430    431.430    431.430    431.430    431.430
# 4  40300.000  40300.000  40300.000  40300.000  40300.000  40300.000
#
# [5 rows x 63 columns]

# %% [markdown]
# ### 📊 Observações iniciais
#
# - A base possui mais de 100 mil registros e 63 colunas
# - Existem variáveis categóricas relacionadas a setores, estados e tipos de gás
# - Os dados de emissões estão distribuídos em colunas numéricas ao longo dos anos (1970–2021)
# - Há presença de valores nulos em algumas colunas categóricas

# %% [markdown]
# 👉 Filtragem

# %%
# Filtrar apenas CO2
co2 = emissoes_gases[emissoes_gases['Gás'] == 'CO2']
co2.head()
# Out:
# Empty DataFrame
# Columns: [Nível 1 - Setor, Nível 2, Nível 3, Nível 4, Nível 5, Nível 6, Emissão / Remoção / Bunker, Gás, Estado, Atividade Econômica, Produto, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
#
# Foram removidos:
# - Dados de remoção (valores negativos)
# - Dados NCI (não contabilizados no inventário nacional)
# - Dados de Bunker (emissões internacionais)
#
# Mantivemos apenas os dados classificados como "Emissão".

# %%
# Verificando categorias existentes
emissoes_gases['Emissão / Remoção / Bunker'].unique()

# Filtrando apenas emissões
emissoes_gases = emissoes_gases[
    emissoes_gases['Emissão / Remoção / Bunker'] == 'Emissão'
]

# Removendo coluna desnecessária
emissoes_gases = emissoes_gases.drop(columns='Emissão / Remoção / Bunker')

# Verificando resultado
print("Nova dimensão:", emissoes_gases.shape)
emissoes_gases.head()
# Out:
# Nova dimensão: (94748, 62)
#          Nível 1 - Setor            Nível 2                    Nível 3  \
# 0  Processos Industriais  Indústria Química            Produção de ABS
# 1  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 2  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 3  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 4  Processos Industriais  Indústria Química  Produção de Ácido Adípico
#
#   Nível 4 Nível 5 Nível 6               Gás Estado Atividade Econômica  \
# 0     NaN     NaN     NaN         COVNM (t)     SP           OUTRA_IND
# 1     NaN     NaN     NaN           N2O (t)     SP           OUTRA_IND
# 2     NaN     NaN     NaN            CO (t)     SP           OUTRA_IND
# 3     NaN     NaN     NaN           NOx (t)     SP           OUTRA_IND
# 4     NaN     NaN     NaN  CO2e (t) GWP-AR2     SP           OUTRA_IND
#
#   Produto  ...       2012       2013       2014       2015       2016  \
# 0     NaN  ...    897.600    897.600    897.600    897.600    897.600
# 1     NaN  ...    130.000    130.000    130.000    130.000    130.000
# 2     NaN  ...   1380.576   1380.576   1380.576   1380.576   1380.576
# 3     NaN  ...    431.430    431.430    431.430    431.430    431.430
# 4     NaN  ...  40300.000  40300.000  40300.000  40300.000  40300.000
#
#         2017       2018       2019       2020       2021
# 0    897.600    897.600    897.600    897.600    897.600
# 1    130.000    130.000    130.000    130.000    130.000
# 2   1380.576   1380.576   1380.576   1380.576   1380.576
# 3    431.430    431.430    431.430    431.430    431.430
# 4  40300.000  40300.000  40300.000  40300.000  40300.000
#
# [5 rows x 62 columns]

# %% [markdown]
# ### 📌 Justificativa
#
# A remoção desses dados garante que a análise seja focada exclusivamente nas emissões efetivas, evitando distorções causadas por valores negativos ou dados fora do escopo do inventário nacional.

# %% [markdown]
# 👉 análise de gás (coluna "Gás")

# %%
emissoes_gases['Gás'].value_counts()
# Out:
# Gás
# CO2e (t) GWP-AR5    8570
# CO2e (t) GTP-AR2    8472
# CO2e (t) GWP-AR2    8472
# CO2e (t) GTP-AR5    8472
# CO2e (t) GTP-AR6    8472
# CO2e (t) GWP-AR4    8472
# CO2e (t) GTP-AR4    8472
# CO2e (t) GWP-AR6    8472
# N2O (t)             5920
# CH4 (t)             4932
# CO2 (t)             4641
# NOx (t)             3801
# CO (t)              3797
# COVNM (t)           3763
# CF4 (t)                6
# C2F6 (t)               6
# SF6 (t)                2
# HFC-32 (t)             1
# HFC-23 (t)             1
# HFC-125 (t)            1
# HFC-134a (t)           1
# HFC-143a (t)           1
# HFC-152a (t)           1
# Name: count, dtype: int64

# %%
emissoes_gases.groupby('Gás').sum(numeric_only=True)
# Out:
#                           1970          1971          1972          1973  \
# CO2e (t) GWP-AR6  1.951328e+09  2.064086e+09  2.079083e+09  1.935368e+09
# COVNM (t)         5.983197e+06  5.642480e+06  5.547361e+06  5.117936e+06
# HFC-125 (t)       6.073291e+02  6.536364e+02  6.999436e+02  7.462509e+02
# HFC-134a (t)      7.495927e+03  7.908473e+03  8.321018e+03  8.733564e+03
# HFC-143a (t)      5.633545e+02  6.069182e+02  6.504818e+02  6.940455e+02
# HFC-152a (t)      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# HFC-23 (t)        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# HFC-32 (t)        1.578500e+02  1.726000e+02  1.873500e+02  2.021000e+02
# N2O (t)           5.932616e+05  6.003838e+05  6.231493e+05  6.246526e+05
# NOx (t)           3.020007e+06  2.855232e+06  2.653311e+06  2.659213e+06
# SF6 (t)           8.590000e+00  8.860000e+00  9.130000e+00  9.400000e+00
#
#                           2018          2019          2020          2021
# Gás
# C2F6 (t)          2.845355e+00  2.707891e+00  2.853239e+00  3.213902e+00
# CF4 (t)           3.822846e+01  3.602815e+01  3.796199e+01  4.276057e+01
# CH4 (t)           1.971751e+07  2.012855e+07  2.047607e+07  2.113969e+07
# CO (t)            7.740160e+06  7.618815e+06  7.511678e+06  7.675710e+06
# CO2 (t)           1.252988e+09  1.394320e+09  1.388751e+09  1.621011e+09
# CO2e (t) GTP-AR2  1.524657e+09  1.672806e+09  1.677053e+09  1.923746e+09
# CO2e (t) GTP-AR4  1.524657e+09  1.672806e+09  1.677053e+09  1.923746e+09
# CO2e (t) GTP-AR5  1.482259e+09  1.629373e+09  1.632201e+09  1.876752e+09
# CO2e (t) GTP-AR6  1.499076e+09  1.646792e+09  1.649939e+09  1.895150e+09
# CO2e (t) GWP-AR2  1.877123e+09  2.033101e+09  2.044626e+09  2.304088e+09
# CO2e (t) GWP-AR4  1.950816e+09  2.108351e+09  2.121037e+09  2.382795e+09
# CO2e (t) GWP-AR5  1.989410e+09  2.147507e+09  2.160065e+09  2.422625e+09
# CO2e (t) GWP-AR6  1.979001e+09  2.137368e+09  2.150175e+09  2.412572e+09
# COVNM (t)         5.290708e+06  5.565853e+06  5.548650e+06  5.604764e+06
# HFC-125 (t)       7.925582e+02  8.388655e+02  8.851727e+02  9.314800e+02
# HFC-134a (t)      9.146109e+03  9.558655e+03  9.971200e+03  1.038375e+04
# HFC-143a (t)      7.376091e+02  7.811727e+02  8.247364e+02  8.683000e+02
# HFC-152a (t)      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# HFC-23 (t)        0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# HFC-32 (t)        2.168500e+02  2.316000e+02  2.463500e+02  2.611000e+02
# N2O (t)           6.209951e+05  6.373808e+05  6.662336e+05  7.062282e+05
# NOx (t)           2.616802e+06  2.631759e+06  2.428566e+06  2.582382e+06
# SF6 (t)           9.670000e+00  9.940000e+00  1.021000e+01  1.048000e+01
#
# [23 rows x 52 columns]

# %% [markdown]
# ## 🔄 Remodelagem dos dados

# %% [markdown]
# Nesta etapa, transformamos o formato da base de dados para facilitar a análise.
#
# Originalmente, os anos estavam distribuídos em múltiplas colunas (formato wide).
# Utilizamos o método `melt` para converter esses dados em um formato long, onde cada linha representa uma observação por ano.
#
# Essa transformação permite realizar análises temporais e agrupamentos de forma mais eficiente.

# %%
# Selecionando colunas de identificação
colunas_info = list(emissoes_gases.loc[:, 'Nível 1 - Setor':'Produto'].columns)

# Selecionando colunas de anos
colunas_emissao = list(emissoes_gases.loc[:, 1970:2021].columns)

# Transformando o DataFrame
emissoes_por_ano = emissoes_gases.melt(
    id_vars=colunas_info,
    value_vars=colunas_emissao,
    var_name='Ano',
    value_name='Emissão'
)

# Visualizando
emissoes_por_ano.head()
# Out:
#          Nível 1 - Setor            Nível 2                    Nível 3  \
# 0  Processos Industriais  Indústria Química            Produção de ABS
# 1  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 2  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 3  Processos Industriais  Indústria Química  Produção de Ácido Adípico
# 4  Processos Industriais  Indústria Química  Produção de Ácido Adípico
#
#   Nível 4 Nível 5 Nível 6               Gás Estado Atividade Econômica  \
# 0     NaN     NaN     NaN         COVNM (t)     SP           OUTRA_IND
# 1     NaN     NaN     NaN           N2O (t)     SP           OUTRA_IND
# 2     NaN     NaN     NaN            CO (t)     SP           OUTRA_IND
# 3     NaN     NaN     NaN           NOx (t)     SP           OUTRA_IND
# 4     NaN     NaN     NaN  CO2e (t) GWP-AR2     SP           OUTRA_IND
#
#   Produto   Ano    Emissão
# 0     NaN  1970        0.0
# 1     NaN  1970     6210.0
# 2     NaN  1970      368.0
# 3     NaN  1970      115.0
# 4     NaN  1970  1925100.0

# %% [markdown]
# 👉 evolução ao longo do tempo

# %%
emissoes_por_ano.groupby('Ano')['Emissão'].sum()
# Out:
# Ano
# 1970    2.096567e+09
# 1971    2.240898e+09
# 1972    2.385491e+09
# 1973    2.603251e+09
# 1974    2.766300e+09
# 1975    2.975280e+09
# 1976    3.189540e+09
# 1977    3.272547e+09
# 1978    3.405971e+09
# 1979    3.565435e+09
# 1980    3.682130e+09
# 1981    3.587020e+09
# 1982    3.620193e+09
# 1983    3.534547e+09
# 1984    3.621661e+09
# 1985    3.744304e+09
# 1986    3.983860e+09
# 1987    4.101135e+09
# 1988    4.194898e+09
# 1989    4.289903e+09
# 1990    1.619736e+10
# 1991    1.624236e+10
# 1992    1.804572e+10
# 1993    1.679371e+10
# 1994    1.891461e+10
# 1995    2.165021e+10
# 1996    1.910101e+10
# 1997    1.995685e+10
# 1998    1.906932e+10
# 1999    1.897495e+10
# 2000    1.871514e+10
# 2001    1.932939e+10
# 2002    2.043104e+10
# 2003    2.495160e+10
# 2004    2.392268e+10
# 2005    2.091411e+10
# 2006    1.787032e+10
# 2007    1.580790e+10
# 2008    1.575162e+10
# 2009    1.285966e+10
# 2010    1.287787e+10
# 2011    1.319019e+10
# 2012    1.411245e+10
# 2013    1.549616e+10
# 2014    1.498223e+10
# 2015    1.590555e+10
# 2016    1.598581e+10
# 2017    1.475039e+10
# 2018    1.511598e+10
# 2019    1.647902e+10
# 2020    1.653754e+10
# 2021    1.880021e+10
# Name: Emissão, dtype: float64

# %% [markdown]
# 👉 qual gás mais polui

# %%
emissoes_por_ano.groupby('Gás')['Emissão'].sum()
# Out:
# Gás
# C2F6 (t)            5.765018e+02
# CF4 (t)             7.135481e+03
# CH4 (t)             7.949268e+08
# CO (t)              5.111531e+08
# CO2 (t)             5.324636e+10
# CO2e (t) GTP-AR2    6.344612e+10
# CO2e (t) GTP-AR4    6.344612e+10
# CO2e (t) GTP-AR5    6.182200e+10
# CO2e (t) GTP-AR6    6.247859e+10
# CO2e (t) GWP-AR2    7.720596e+10
# CO2e (t) GWP-AR4    8.015921e+10
# CO2e (t) GWP-AR5    8.181375e+10
# CO2e (t) GWP-AR6    8.132316e+10
# COVNM (t)           2.242130e+08
# HFC-125 (t)         9.795580e+03
# HFC-134a (t)        1.394731e+05
# HFC-143a (t)        9.039400e+03
# HFC-152a (t)        5.706000e+02
# HFC-23 (t)          1.197840e+03
# HFC-32 (t)          2.367750e+03
# N2O (t)             2.240066e+07
# NOx (t)             9.976123e+07
# SF6 (t)             4.705800e+02
# Name: Emissão, dtype: float64

# %% [markdown]
# 👉 análise temporal por gás

# %%
emissoes_por_ano.groupby(['Ano', 'Gás'])['Emissão'].sum()
# Out:
# Ano   Gás
# 1970  C2F6 (t)      1.395662e+00
#       CF4 (t)       2.134453e+01
#       CH4 (t)       7.255090e+06
#       CO (t)        8.184649e+06
#       CO2 (t)       8.931564e+07
#                         ...
# 2021  HFC-23 (t)    0.000000e+00
#       HFC-32 (t)    2.611000e+02
#       N2O (t)       7.062282e+05
#       NOx (t)       2.582382e+06
#       SF6 (t)       1.048000e+01
# Name: Emissão, Length: 1196, dtype: float64

# %% [markdown]
# ### 📌 Insight 1
#
# Observa-se uma tendência de crescimento nas emissões ao longo do tempo, com aceleração a partir dos anos 2000. Esse comportamento pode estar associado ao aumento da industrialização, expansão agrícola e maior consumo de energia.

# %%
emissoes_por_ano.groupby('Gás')['Emissão'].sum().sort_values(ascending=False)
# Out:
# Gás
# CO2e (t) GWP-AR5    8.181375e+10
# CO2e (t) GWP-AR6    8.132316e+10
# CO2e (t) GWP-AR4    8.015921e+10
# CO2e (t) GWP-AR2    7.720596e+10
# CO2e (t) GTP-AR4    6.344612e+10
# CO2e (t) GTP-AR2    6.344612e+10
# CO2e (t) GTP-AR6    6.247859e+10
# CO2e (t) GTP-AR5    6.182200e+10
# CO2 (t)             5.324636e+10
# CH4 (t)             7.949268e+08
# CO (t)              5.111531e+08
# COVNM (t)           2.242130e+08
# NOx (t)             9.976123e+07
# N2O (t)             2.240066e+07
# HFC-134a (t)        1.394731e+05
# HFC-125 (t)         9.795580e+03
# HFC-143a (t)        9.039400e+03
# CF4 (t)             7.135481e+03
# HFC-32 (t)          2.367750e+03
# HFC-23 (t)          1.197840e+03
# C2F6 (t)            5.765018e+02
# HFC-152a (t)        5.706000e+02
# SF6 (t)             4.705800e+02
# Name: Emissão, dtype: float64

# %%
emissoes_por_ano.groupby('Ano')['Emissão'].sum()
# Out:
# Ano
# 1970    2.096567e+09
# 1971    2.240898e+09
# 1972    2.385491e+09
# 1973    2.603251e+09
# 1974    2.766300e+09
# 1975    2.975280e+09
# 1976    3.189540e+09
# 1977    3.272547e+09
# 1978    3.405971e+09
# 1979    3.565435e+09
# 1980    3.682130e+09
# 1981    3.587020e+09
# 1982    3.620193e+09
# 1983    3.534547e+09
# 1984    3.621661e+09
# 1985    3.744304e+09
# 1986    3.983860e+09
# 1987    4.101135e+09
# 1988    4.194898e+09
# 1989    4.289903e+09
# 1990    1.619736e+10
# 1991    1.624236e+10
# 1992    1.804572e+10
# 1993    1.679371e+10
# 1994    1.891461e+10
# 1995    2.165021e+10
# 1996    1.910101e+10
# 1997    1.995685e+10
# 1998    1.906932e+10
# 1999    1.897495e+10
# 2000    1.871514e+10
# 2001    1.932939e+10
# 2002    2.043104e+10
# 2003    2.495160e+10
# 2004    2.392268e+10
# 2005    2.091411e+10
# 2006    1.787032e+10
# 2007    1.580790e+10
# 2008    1.575162e+10
# 2009    1.285966e+10
# 2010    1.287787e+10
# 2011    1.319019e+10
# 2012    1.411245e+10
# 2013    1.549616e+10
# 2014    1.498223e+10
# 2015    1.590555e+10
# 2016    1.598581e+10
# 2017    1.475039e+10
# 2018    1.511598e+10
# 2019    1.647902e+10
# 2020    1.653754e+10
# 2021    1.880021e+10
# Name: Emissão, dtype: float64

# %%
emissoes_gases.loc[:,'Nível 1 - Setor':'Produto'].columns
# Out:
# Index(['Nível 1 - Setor', 'Nível 2', 'Nível 3', 'Nível 4', 'Nível 5',
#        'Nível 6', 'Gás', 'Estado', 'Atividade Econômica', 'Produto'],
#       dtype='object')

# %%
colunas_info = list(emissoes_gases.loc[:,'Nível 1 - Setor':'Produto'].columns)
colunas_info
# Out:
# ['Nível 1 - Setor',
#  'Nível 2',
#  'Nível 3',
#  'Nível 4',
#  'Nível 5',
#  'Nível 6',
#  'Gás',
#  'Estado',
#  'Atividade Econômica',
#  'Produto']

# %%
colunas_emissao = list(emissoes_gases.loc[:,1970:2021].columns)
colunas_emissao
# Out:
# [1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
emissoes_gases.melt(id_vars = colunas_info, value_vars = colunas_emissao, var_name = 'Ano' , value_name = 'Emissão')
# Out:
#                             Nível 1 - Setor              Nível 2  \
# 0                     Processos Industriais    Indústria Química
# 1                     Processos Industriais    Indústria Química
# 2                     Processos Industriais    Indústria Química
# 3                     Processos Industriais    Indústria Química
# 4                     Processos Industriais    Indústria Química
# ...                                     ...                  ...
# 4926891  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 4926892  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 4926893  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 4926894  Mudança de Uso da Terra e Floresta  Resíduos Florestais
# 4926895  Mudança de Uso da Terra e Floresta  Resíduos Florestais
#
#                            Nível 3 Nível 4       Nível 5 Nível 6  \
# 0                  Produção de ABS     NaN           NaN     NaN
# 1        Produção de Ácido Adípico     NaN           NaN     NaN
# 2        Produção de Ácido Adípico     NaN           NaN     NaN
# 3        Produção de Ácido Adípico     NaN           NaN     NaN
# 4        Produção de Ácido Adípico     NaN           NaN     NaN
# ...                            ...     ...           ...     ...
# 4926891                   Pantanal     NaN  Desmatamento     NaN
# 4926892                   Pantanal     NaN  Desmatamento     NaN
# 4926893                   Pantanal     NaN  Desmatamento     NaN
# 4926894                   Pantanal     NaN  Desmatamento     NaN
# 4926895                   Pantanal     NaN  Desmatamento     NaN
#
#                       Gás Estado Atividade Econômica Produto   Ano    Emissão
# 0               COVNM (t)     SP           OUTRA_IND     NaN  1970        0.0
# 1                 N2O (t)     SP           OUTRA_IND     NaN  1970     6210.0
# 2                  CO (t)     SP           OUTRA_IND     NaN  1970      368.0
# 3                 NOx (t)     SP           OUTRA_IND     NaN  1970      115.0
# 4        CO2e (t) GWP-AR2     SP           OUTRA_IND     NaN  1970  1925100.0
# ...                   ...    ...                 ...     ...   ...        ...
 86, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 164, 165, 170, 173, 174, 179, 180, 181, 182, 183, 184, 297, 298, 299, 300, 301, 302, 303, 304, 305, 404, 405, 406, 419, 420, 421, 434, 440, 441, 442, 482, 489, 490, 491, 492, 501, 502, 503, 504, 513, 514, 515, 516, 11856, 11857, 11858, 11859, 11860, 11861, 11862, 11863, 11864, 11865, 11866, 11867, 11868, 11869, 11870, 11871, 11872, 11873, ...], 'CO2e (t) GTP-AR2': [5, 9, 13, 17, 22, 25, 28, 31, 34, 37, 40, 45, 48, 53, 60, 66, 69, 74, 78, 88, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 168, 169, 172, 177, 178, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 416, 417, 418, 431, 432, 433, 436, 439, 467, 468, 469, 470, 478, 481, 484, 497, 498, 499, 500, 509, 510, 511, 512, 521, 522, ...], 'CO2e (t) GTP-AR4': [526, 528, 530, 532, 534, 536, 538, 540, 542, 544, 546, 548, 550, 552, 554, 556, 558, 560, 562, 564, 590, 591, 592, 593, 594, 595, 59 ...

# %% [markdown]
# ### 📌 Insight
#
# O CO₂ equivalente (CO2e) apresenta o maior volume de emissões totais.
# No entanto, essa métrica representa uma agregação de diferentes gases, sendo necessário analisar os gases individualmente para uma compreensão mais precisa.
#
# Entre os gases individuais, o CO₂ se destaca como principal responsável pelas emissões, indicando que estratégias de redução devem priorizar esse componente.

# %%
emissoes_por_ano.groupby('Gás').get_group('CO2 (t)')
# Out:
#                             Nível 1 - Setor                     Nível 2  \
# 18                    Processos Industriais           Indústria Química
# 23                    Processos Industriais           Indústria Química
# 26                    Processos Industriais           Indústria Química
# 29                    Processos Industriais           Indústria Química
# 32                    Processos Industriais           Indústria Química
# ...                                     ...                         ...
# 4926255  Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 4926272  Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 4926273  Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 4926290  Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
# 4926291  Mudança de Uso da Terra e Floresta  Alterações de Uso da Terra
#
#                            Nível 3            Nível 4  \
# 18       Produção de Acrilonitrila                NaN
# 23              Produção de Amônia                NaN
# 26              Produção de Amônia                NaN
# 29              Produção de Amônia                NaN
# 32              Produção de Amônia                NaN
# ...                            ...                ...
# 4926255                   Pantanal  em Área Protegida
# 4926272                   Pantanal  em Área Protegida
# 4926273                   Pantanal  em Área Protegida
# 4926290                   Pantanal  em Área Protegida
# 4926291                   Pantanal  em Área Protegida
#
#                                  Nível 5  \
# 18                                   NaN
# 23                                   NaN
# 26                                   NaN
# 29                                   NaN
# 32                                   NaN
# ...                                  ...
# 4926255  Outras Mudanças de uso da terra
# 4926272                      Regeneração
# 4926273                      Regeneração
# 4926290                      Regeneração
# 4926291                      Regeneração
#
#                                                    Nível 6      Gás Estado  \
# 18                                                     NaN  CO2 (t)     BA
# 23                                                     NaN  CO2 (t)     RJ
# 26                                                     NaN  CO2 (t)     MG
# 29                                                     NaN  CO2 (t)     BA
# 32                                                     NaN  CO2 (t)     SE
# ...                                                    ...      ...    ...
# 4926255               Uso agropecuário -- Uso agropecuário  CO2 (t)     MS
# 4926272            Uso agropecuário -- Floresta secundária  CO2 (t)     MT
# 4926273            Uso agropecuário -- Floresta secundária  CO2 (t)     MS
# 4926290  Uso agropecuário -- Vegetação não florestal se...  CO2 (t)     MT
# 4926291  Uso agropecuário -- Vegetação não florestal se...  CO2 (t)     MS
#
#         Atividade Econômica Produto   Ano       Emissão
# 18                OUTRA_IND     NaN  1970      0.000000
# 23                OUTRA_IND     NaN  1970      0.000000
# 26                OUTRA_IND     NaN  1970      0.000000
# 29                OUTRA_IND     NaN  1970  10742.465792
# 32                OUTRA_IND     NaN  1970      0.000000
# ...                     ...     ...   ...           ...
# 4926255             AGROPEC     NaN  2021      0.000000
# 4926272             AGROPEC     NaN  2021    374.000000
# 4926273             AGROPEC     NaN  2021   8613.000000
# 4926290             AGROPEC     NaN  2021    934.000000
# 4926291             AGROPEC     NaN  2021  17515.000000
#
# [241332 rows x 12 columns]

# %% [markdown]
# ### 📊 Interpretação
#
# Observa-se uma concentração significativa das emissões em poucos tipos de gases, com destaque para o CO₂.
# Isso indica que ações focadas nesses principais gases podem gerar maior impacto na redução das emissões totais.

# %%
import matplotlib.pyplot as plt

gases = emissoes_por_ano.groupby('Gás')['Emissão'] \
    .sum() \
    .sort_values(ascending=False)

gases.head(10).plot(kind='bar')

plt.title('Top 10 gases mais emitidos')
plt.ylabel('Emissão total')
plt.xlabel('Gás')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Gráfico que mostra evolução de emissões ao longo do tempo

# %%
emissoes_por_ano.groupby('Ano')['Emissão'].sum().plot()
plt.title('Evolução das emissões ao longo do tempo')
plt.show()

# %% [markdown]
# 👉 análise por setor

# %%
emissoes_por_ano.groupby('Nível 1 - Setor')['Emissão'].sum()
# Out:
# Nível 1 - Setor
# Agropecuária                          1.147284e+11
# Energia                               1.205314e+11
# Mudança de Uso da Terra e Floresta    3.524898e+11
# Processos Industriais                 2.849965e+10
# Resíduos                              1.034465e+10
# Name: Emissão, dtype: float64

# %%
emissoes_por_ano.groupby('Gás').sum(numeric_only = True)
# Out:
#                        Emissão
# Gás
# C2F6 (t)          5.765018e+02
# CF4 (t)           7.135481e+03
# CH4 (t)           7.949268e+08
# CO (t)            5.111531e+08
# CO2 (t)           5.324636e+10
# CO2e (t) GTP-AR2  6.344612e+10
# CO2e (t) GTP-AR4  6.344612e+10
# CO2e (t) GTP-AR5  6.182200e+10
# CO2e (t) GTP-AR6  6.247859e+10
# CO2e (t) GWP-AR2  7.720596e+10
# CO2e (t) GWP-AR4  8.015921e+10
# CO2e (t) GWP-AR5  8.181375e+10
# CO2e (t) GWP-AR6  8.132316e+10
# COVNM (t)         2.242130e+08
# HFC-125 (t)       9.795580e+03
# HFC-134a (t)      1.394731e+05
# HFC-143a (t)      9.039400e+03
# HFC-152a (t)      5.706000e+02
# HFC-23 (t)        1.197840e+03
# HFC-32 (t)        2.367750e+03
# N2O (t)           2.240066e+07
# NOx (t)           9.976123e+07
# SF6 (t)           4.705800e+02

# %%
emissoes_por_ano.groupby('Gás')[['Emissão']].sum()
# Out:
#                        Emissão
# Gás
# C2F6 (t)          5.765018e+02
# CF4 (t)           7.135481e+03
# CH4 (t)           7.949268e+08
# CO (t)            5.111531e+08
# CO2 (t)           5.324636e+10
# CO2e (t) GTP-AR2  6.344612e+10
# CO2e (t) GTP-AR4  6.344612e+10
# CO2e (t) GTP-AR5  6.182200e+10
# CO2e (t) GTP-AR6  6.247859e+10
# CO2e (t) GWP-AR2  7.720596e+10
# CO2e (t) GWP-AR4  8.015921e+10
# CO2e (t) GWP-AR5  8.181375e+10
# CO2e (t) GWP-AR6  8.132316e+10
# COVNM (t)         2.242130e+08
# HFC-125 (t)       9.795580e+03
# HFC-134a (t)      1.394731e+05
# HFC-143a (t)      9.039400e+03
# HFC-152a (t)      5.706000e+02
# HFC-23 (t)        1.197840e+03
# HFC-32 (t)        2.367750e+03
# N2O (t)           2.240066e+07
# NOx (t)           9.976123e+07
# SF6 (t)           4.705800e+02

# %%
emissao_por_gas = emissoes_por_ano.groupby('Gás')[['Emissão']].sum()

# %%
emissao_por_gas = emissoes_por_ano.groupby('Gás')[['Emissão']].sum().sort_values('Emissão', ascending = False)
emissao_por_gas
# Out:
#                        Emissão
# Gás
# CO2e (t) GWP-AR5  8.181375e+10
# CO2e (t) GWP-AR6  8.132316e+10
# CO2e (t) GWP-AR4  8.015921e+10
# CO2e (t) GWP-AR2  7.720596e+10
# CO2e (t) GTP-AR4  6.344612e+10
# CO2e (t) GTP-AR2  6.344612e+10
# CO2e (t) GTP-AR6  6.247859e+10
# CO2e (t) GTP-AR5  6.182200e+10
# CO2 (t)           5.324636e+10
# CH4 (t)           7.949268e+08
# CO (t)            5.111531e+08
# COVNM (t)         2.242130e+08
# NOx (t)           9.976123e+07
# N2O (t)           2.240066e+07
# HFC-134a (t)      1.394731e+05
# HFC-125 (t)       9.795580e+03
# HFC-143a (t)      9.039400e+03
# CF4 (t)           7.135481e+03
# HFC-32 (t)        2.367750e+03
# HFC-23 (t)        1.197840e+03
# C2F6 (t)          5.765018e+02
# HFC-152a (t)      5.706000e+02
# SF6 (t)           4.705800e+02

# %%
emissao_por_gas.plot(kind = 'barh', figsize = (10,6));

# %%
emissao_por_gas.iloc[0:9]
# Out:
#                        Emissão
# Gás
# CO2e (t) GWP-AR5  8.181375e+10
# CO2e (t) GWP-AR6  8.132316e+10
# CO2e (t) GWP-AR4  8.015921e+10
# CO2e (t) GWP-AR2  7.720596e+10
# CO2e (t) GTP-AR4  6.344612e+10
# CO2e (t) GTP-AR2  6.344612e+10
# CO2e (t) GTP-AR6  6.247859e+10
# CO2e (t) GTP-AR5  6.182200e+10
# CO2 (t)           5.324636e+10

# %% [markdown]
# ### 📌 Insight principal
#
# Os gases do tipo CO₂ equivalente (CO2e) representam aproximadamente 99% das emissões totais no período analisado.
#
# No entanto, essa métrica agrega diferentes gases em uma única unidade, o que pode superestimar a participação do CO₂ na comparação com gases individuais.
#
# Portanto, é importante analisar separadamente os gases individuais para uma interpretação mais precisa.

# %%
print(f'A emissão de CO2 corresponde a {float((emissao_por_gas.iloc[0:9].sum()/emissao_por_gas.sum()).iloc[0])*100:.2f} % de emissão total de gases estufa no Brasil de 1970 a 2021.')
# Out:
# A emissão de CO2 corresponde a 99.74 % de emissão total de gases estufa no Brasil de 1970 a 2021.

# %%
emissao_por_gas.head(10).plot(
    kind='barh',
    figsize=(10,6),
    title='Top 10 gases mais emitidos'
)
# Out:
# <Axes: title={'center': 'Top 10 gases mais emitidos'}, ylabel='Gás'>

# %% [markdown]
# ### 📌 Insight – Evolução temporal
#
# Observa-se uma tendência de crescimento das emissões ao longo do tempo, com intensificação a partir dos anos 2000. Esse comportamento pode estar associado ao aumento da atividade econômica, expansão agrícola e maior consumo de energia no país.

# %%
emissoes_por_ano.groupby('Nível 1 - Setor')['Emissão'] \
    .sum() \
    .sort_values(ascending=False)
# Out:
# Nível 1 - Setor
# Mudança de Uso da Terra e Floresta    3.524898e+11
# Energia                               1.205314e+11
# Agropecuária                          1.147284e+11
# Processos Industriais                 2.849965e+10
# Resíduos                              1.034465e+10
# Name: Emissão, dtype: float64

# %% [markdown]
# ### 📌 Insight – Setores
#
# O setor de Mudança de Uso da Terra e Floresta é o maior responsável pelas emissões no Brasil, superando significativamente os demais setores.
#
# Esse resultado indica que o desmatamento e mudanças no uso do solo têm um impacto maior do que a indústria ou energia, diferentemente de países desenvolvidos.

# %%
emissoes_por_ano.groupby('Nível 1 - Setor')['Emissão'] \
    .sum() \
    .sort_values(ascending=False) \
    .plot(kind='bar', figsize=(10,5))

plt.title('Emissões por setor')
plt.ylabel('Emissão total')
plt.xlabel('Setor')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Estados com maior atividade agropecuária e desmatamento apresentam maiores níveis de emissão.

# %%
emissao_por_estado = emissoes_por_ano.groupby('Estado')['Emissão'] \
    .sum() \
    .sort_values(ascending=False)

emissao_por_estado.head(10).plot(kind='bar', figsize=(10,5))

plt.title('Top 10 estados mais emissores')
plt.ylabel('Emissão total')
plt.xlabel('Estado')
plt.show()

# %% [markdown]
# O crescimento das emissões está fortemente associado ao setor de uso da terra ao longo dos anos.

# %%
emissoes_por_ano.groupby(['Ano', 'Nível 1 - Setor'])['Emissão'] \
    .sum() \
    .unstack() \
    .plot(figsize=(12,6))

plt.title('Evolução das emissões por setor')
plt.ylabel('Emissão')
plt.show()

# %% [markdown]
# Apesar da presença de diversos gases, mais de 99% das emissões são dominadas por CO₂ equivalente, indicando alta concentração de impacto em poucos fatores.

# %%
plt.style.use('ggplot')

# %%
evolucao = emissoes_por_ano.groupby('Ano')['Emissão'].sum()

crescimento = ((evolucao.iloc[-1] - evolucao.iloc[0]) / evolucao.iloc[0]) * 100

print(f'Crescimento total das emissões: {crescimento:.2f}%')
# Out:
# Crescimento total das emissões: 796.71%

# %%
top_gases = emissoes_por_ano.groupby('Gás')['Emissão'] \
    .sum() \
    .sort_values(ascending=False) \
    .head(5) \
    .index

emissoes_por_ano[emissoes_por_ano['Gás'].isin(top_gases)] \
    .groupby(['Ano', 'Gás'])['Emissão'] \
    .sum() \
    .unstack() \
    .plot(figsize=(12,6))

plt.title('Evolução dos principais gases')
plt.show()

# %% [markdown]
# Apesar da presença de diversos gases, mais de 99% das emissões são dominadas por CO₂ equivalente, indicando alta concentração de impacto em poucos fatores.

# %% [markdown]
# ### 📌 Insight 1
# O CO₂ é o principal responsável pelas emissões ao longo de todo o período analisado, representando a maior parcela dos gases emitidos.
#
# ### 📌 Insight 2
# O setor de energia apresenta crescimento consistente nas emissões após os anos 2000, indicando aumento da demanda energética.
#
# ### 📌 Insight 3
# Alguns setores apresentam queda recente, possivelmente relacionada a políticas ambientais ou mudanças econômicas.

# %% [markdown]
# Nesta etapa, analisamos a relação entre os tipos de gases e os setores econômicos, com o objetivo de identificar quais atividades mais contribuem para a emissão de cada gás.

# %%
## 🔍 Relação entre gases e setores

# %%
gas_por_setor = emissoes_por_ano.groupby(
    ['Gás', 'Nível 1 - Setor']
)[['Emissão']].sum()

# %% [markdown]
# 👉 Qual setor mais polui para CADA gás:

# %%
gas_por_setor.groupby(level=0)['Emissão'].idxmax()
# Out:
# Gás
# C2F6 (t)                            (C2F6 (t), Processos Industriais)
# CF4 (t)                              (CF4 (t), Processos Industriais)
# CH4 (t)                                       (CH4 (t), Agropecuária)
# CO (t)                                              (CO (t), Energia)
# CO2 (t)                 (CO2 (t), Mudança de Uso da Terra e Floresta)
# CO2e (t) GTP-AR2    (CO2e (t) GTP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR4    (CO2e (t) GTP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR5    (CO2e (t) GTP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR6    (CO2e (t) GTP-AR6, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR2    (CO2e (t) GWP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR4    (CO2e (t) GWP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR5    (CO2e (t) GWP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR6    (CO2e (t) GWP-AR6, Mudança de Uso da Terra e F...
# COVNM (t)                          (COVNM (t), Processos Industriais)
# HFC-125 (t)                      (HFC-125 (t), Processos Industriais)
# HFC-134a (t)                    (HFC-134a (t), Processos Industriais)
# HFC-143a (t)                    (HFC-143a (t), Processos Industriais)
# HFC-152a (t)                    (HFC-152a (t), Processos Industriais)
# HFC-23 (t)                        (HFC-23 (t), Processos Industriais)
# HFC-32 (t)                        (HFC-32 (t), Processos Industriais)
# N2O (t)                                       (N2O (t), Agropecuária)
# NOx (t)                                            (NOx (t), Energia)
# SF6 (t)                              (SF6 (t), Processos Industriais)
# Name: Emissão, dtype: object

# %%
top_setores = emissoes_por_ano.groupby('Nível 1 - Setor')['Emissão'] \
    .sum() \
    .sort_values(ascending=False)

top_setores.plot(kind='bar', figsize=(10,5))

plt.title('Emissões por setor econômico')
plt.xticks(rotation=45)
plt.show()

# %%
pivot = emissoes_por_ano.pivot_table(
    values='Emissão',
    index='Nível 1 - Setor',
    columns='Gás',
    aggfunc='sum'
)

pivot.head()
# Out:
# Gás                                   C2F6 (t)      CF4 (t)       CH4 (t)  \
# Nível 1 - Setor
# Agropecuária                               NaN          NaN  5.928481e+08
# Energia                                    NaN          NaN  3.429034e+07
# Mudança de Uso da Terra e Floresta         NaN          NaN  8.662166e+07
# Processos Industriais               576.501774  7135.481282  2.092132e+06
# Resíduos                                   NaN          NaN  7.907453e+07
#
# Gás                                       CO (t)       CO2 (t)  \
# Nível 1 - Setor
# Agropecuária                        7.132479e+07  5.411750e+08
# Energia                             3.959769e+08  1.261352e+10
# Mudança de Uso da Terra e Floresta           NaN  3.733930e+10
# Processos Industriais               4.385133e+07  2.729603e+09
# Resíduos                                     NaN  2.276264e+07
#
# Gás                                 CO2e (t) GTP-AR2  CO2e (t) GTP-AR4  \
# Nível 1 - Setor
# Agropecuária                            8.297112e+09      8.297112e+09
# Energia                                 1.306899e+10      1.306899e+10
# Mudança de Uso da Terra e Floresta      3.850044e+10      3.850044e+10
# Processos Industriais                   3.086813e+09      3.086813e+09
# Resíduos                                4.927667e+08      4.927667e+08
#
# Gás                                 CO2e (t) GTP-AR5  CO2e (t) GTP-AR6  \
# Nível 1 - Setor
# Agropecuária                            7.065371e+09      7.462618e+09
# Energia                                 1.299683e+10      1.304584e+10
# Mudança de Uso da Terra e Floresta      3.831675e+10      3.843359e+10
# Processos Industriais                   3.039311e+09      3.077736e+09
# Resíduos                                4.037413e+08      4.588171e+08
#
# Gás                                 CO2e (t) GWP-AR2  ...     COVNM (t)  \
# Nível 1 - Setor                                       ...
# Agropecuária                            1.849256e+10  ...           NaN
# Energia                                 1.365971e+10  ...  6.335071e+07
# Mudança de Uso da Terra e Floresta      3.999424e+10  ...           NaN
# Processos Industriais                   3.290424e+09  ...  1.608623e+08
# Resíduos                                1.769016e+09  ...           NaN
#
# Gás                                 HFC-125 (t)  HFC-134a (t)  HFC-143a (t)  \
# Nível 1 - Setor
# Agropecuária                                NaN           NaN           NaN
# Energia                                     NaN           NaN           NaN
# Mudança de Uso da Terra e Floresta          NaN           NaN           NaN
# Processos Industriais                   9795.58      139473.1        9039.4
# Resíduos                                    NaN           NaN           NaN
#
# Gás                                 HFC-152a (t)  HFC-23 (t)  HFC-32 (t)  \
# Nível 1 - Setor
# Agropecuária                                 NaN         NaN         NaN
# Energia                                      NaN         NaN         NaN
# Mudança de Uso da Terra e Floresta           NaN         NaN         NaN
# Processos Industriais                      570.6     1197.84     2367.75
# Resíduos                                     NaN         NaN         NaN
#
# Gás                                      N2O (t)       NOx (t)  SF6 (t)
# Nível 1 - Setor
# Agropecuária                        1.774702e+07  2.602719e+06      NaN
# Energia                             1.051929e+06  9.361215e+07      NaN
# Mudança de Uso da Terra e Floresta  2.695524e+06           NaN      NaN
# Processos Industriais               6.297715e+05  3.546360e+06   470.58
# Resíduos                            2.764127e+05           NaN      NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Nesta etapa, analisamos a relação entre gases e setores econômicos de forma bidirecional:
#
# - Identificamos qual setor mais contribui para a emissão de cada gás
# - E também qual gás é mais relevante dentro de cada setor
#
# Essa análise permite entender melhor a origem das emissões e direcionar estratégias mais eficazes de redução.

# %%
## 🔄 Relação entre gases e setores (análise avançada)

# %% [markdown]
# ### 📌 Insight – Relação gás × setor
#
# Para a maioria dos gases, o setor de Mudança de Uso da Terra e Floresta aparece como principal responsável pelas emissões.
#
# Isso indica que o desmatamento e alterações no uso do solo têm impacto significativo não apenas no CO₂, mas também em outros gases do efeito estufa.

# %%
gas_por_setor.groupby(level = 0).idxmax()
# Out:
#                                                             Emissão
# Gás
# C2F6 (t)                          (C2F6 (t), Processos Industriais)
# CF4 (t)                            (CF4 (t), Processos Industriais)
# CH4 (t)                                     (CH4 (t), Agropecuária)
# CO (t)                                            (CO (t), Energia)
# CO2 (t)               (CO2 (t), Mudança de Uso da Terra e Floresta)
# CO2e (t) GTP-AR2  (CO2e (t) GTP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR4  (CO2e (t) GTP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR5  (CO2e (t) GTP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR6  (CO2e (t) GTP-AR6, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR2  (CO2e (t) GWP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR4  (CO2e (t) GWP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR5  (CO2e (t) GWP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR6  (CO2e (t) GWP-AR6, Mudança de Uso da Terra e F...
# COVNM (t)                        (COVNM (t), Processos Industriais)
# HFC-125 (t)                    (HFC-125 (t), Processos Industriais)
# HFC-134a (t)                  (HFC-134a (t), Processos Industriais)
# HFC-143a (t)                  (HFC-143a (t), Processos Industriais)
# HFC-152a (t)                  (HFC-152a (t), Processos Industriais)
# HFC-23 (t)                      (HFC-23 (t), Processos Industriais)
# HFC-32 (t)                      (HFC-32 (t), Processos Industriais)
# N2O (t)                                     (N2O (t), Agropecuária)
# NOx (t)                                          (NOx (t), Energia)
# SF6 (t)                            (SF6 (t), Processos Industriais)

# %%
gas_por_setor.groupby(level = 0).idxmax()
# Out:
#                                                             Emissão
# Gás
# C2F6 (t)                          (C2F6 (t), Processos Industriais)
# CF4 (t)                            (CF4 (t), Processos Industriais)
# CH4 (t)                                     (CH4 (t), Agropecuária)
# CO (t)                                            (CO (t), Energia)
# CO2 (t)               (CO2 (t), Mudança de Uso da Terra e Floresta)
# CO2e (t) GTP-AR2  (CO2e (t) GTP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR4  (CO2e (t) GTP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR5  (CO2e (t) GTP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR6  (CO2e (t) GTP-AR6, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR2  (CO2e (t) GWP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR4  (CO2e (t) GWP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR5  (CO2e (t) GWP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR6  (CO2e (t) GWP-AR6, Mudança de Uso da Terra e F...
# COVNM (t)                        (COVNM (t), Processos Industriais)
# HFC-125 (t)                    (HFC-125 (t), Processos Industriais)
# HFC-134a (t)                  (HFC-134a (t), Processos Industriais)
# HFC-143a (t)                  (HFC-143a (t), Processos Industriais)
# HFC-152a (t)                  (HFC-152a (t), Processos Industriais)
# HFC-23 (t)                      (HFC-23 (t), Processos Industriais)
# HFC-32 (t)                      (HFC-32 (t), Processos Industriais)
# N2O (t)                                     (N2O (t), Agropecuária)
# NOx (t)                                          (NOx (t), Energia)
# SF6 (t)                            (SF6 (t), Processos Industriais)

# %%
gas_por_setor.groupby(level = 0).max()
# Out:
#                        Emissão
# Gás
# C2F6 (t)          5.765018e+02
# CF4 (t)           7.135481e+03
# CH4 (t)           5.928481e+08
# CO (t)            3.959769e+08
# CO2 (t)           3.733930e+10
# CO2e (t) GTP-AR2  3.850044e+10
# CO2e (t) GTP-AR4  3.850044e+10
# CO2e (t) GTP-AR5  3.831675e+10
# CO2e (t) GTP-AR6  3.843359e+10
# CO2e (t) GWP-AR2  3.999424e+10
# CO2e (t) GWP-AR4  4.030837e+10
# CO2e (t) GWP-AR5  4.051523e+10
# CO2e (t) GWP-AR6  4.049216e+10
# COVNM (t)         1.608623e+08
# HFC-125 (t)       9.795580e+03
# HFC-134a (t)      1.394731e+05
# HFC-143a (t)      9.039400e+03
# HFC-152a (t)      5.706000e+02
# HFC-23 (t)        1.197840e+03
# HFC-32 (t)        2.367750e+03
# N2O (t)           1.774702e+07
# NOx (t)           9.361215e+07
# SF6 (t)           4.705800e+02

# %%
valores_max = gas_por_setor.groupby(level = 0).max().values

# %%
tabela_sumarizada = gas_por_setor.groupby(level = 0).idxmax()
tabela_sumarizada.insert(1, 'Quantidade de emissão',valores_max)
tabela_sumarizada
# Out:
#                                                             Emissão  \
# Gás
# C2F6 (t)                          (C2F6 (t), Processos Industriais)
# CF4 (t)                            (CF4 (t), Processos Industriais)
# CH4 (t)                                     (CH4 (t), Agropecuária)
# CO (t)                                            (CO (t), Energia)
# CO2 (t)               (CO2 (t), Mudança de Uso da Terra e Floresta)
# CO2e (t) GTP-AR2  (CO2e (t) GTP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR4  (CO2e (t) GTP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR5  (CO2e (t) GTP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GTP-AR6  (CO2e (t) GTP-AR6, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR2  (CO2e (t) GWP-AR2, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR4  (CO2e (t) GWP-AR4, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR5  (CO2e (t) GWP-AR5, Mudança de Uso da Terra e F...
# CO2e (t) GWP-AR6  (CO2e (t) GWP-AR6, Mudança de Uso da Terra e F...
# COVNM (t)                        (COVNM (t), Processos Industriais)
# HFC-125 (t)                    (HFC-125 (t), Processos Industriais)
# HFC-134a (t)                  (HFC-134a (t), Processos Industriais)
# HFC-143a (t)                  (HFC-143a (t), Processos Industriais)
# HFC-152a (t)                  (HFC-152a (t), Processos Industriais)
# HFC-23 (t)                      (HFC-23 (t), Processos Industriais)
# HFC-32 (t)                      (HFC-32 (t), Processos Industriais)
# N2O (t)                                     (N2O (t), Agropecuária)
# NOx (t)                                          (NOx (t), Energia)
# SF6 (t)                            (SF6 (t), Processos Industriais)
#
#                   Quantidade de emissão
# Gás
# C2F6 (t)                   5.765018e+02
# CF4 (t)                    7.135481e+03
# CH4 (t)                    5.928481e+08
# CO (t)                     3.959769e+08
# CO2 (t)                    3.733930e+10
# CO2e (t) GTP-AR2           3.850044e+10
# CO2e (t) GTP-AR4           3.850044e+10
# CO2e (t) GTP-AR5           3.831675e+10
# CO2e (t) GTP-AR6           3.843359e+10
# CO2e (t) GWP-AR2           3.999424e+10
# CO2e (t) GWP-AR4           4.030837e+10
# CO2e (t) GWP-AR5           4.051523e+10
# CO2e (t) GWP-AR6           4.049216e+10
# COVNM (t)                  1.608623e+08
# HFC-125 (t)                9.795580e+03
# HFC-134a (t)               1.394731e+05
# HFC-143a (t)               9.039400e+03
# HFC-152a (t)               5.706000e+02
# HFC-23 (t)                 1.197840e+03
# HFC-32 (t)                 2.367750e+03
# N2O (t)                    1.774702e+07
# NOx (t)                    9.361215e+07
# SF6 (t)                    4.705800e+02

# %%
gas_por_setor.swaplevel(0, 1)
# Out:
#                                                   Emissão
# Nível 1 - Setor                    Gás
# Processos Industriais              C2F6 (t)  5.765018e+02
#                                    CF4 (t)   7.135481e+03
# Agropecuária                       CH4 (t)   5.928481e+08
# Energia                            CH4 (t)   3.429034e+07
# Mudança de Uso da Terra e Floresta CH4 (t)   8.662166e+07
# ...                                                   ...
# Resíduos                           N2O (t)   2.764127e+05
# Agropecuária                       NOx (t)   2.602719e+06
# Energia                            NOx (t)   9.361215e+07
# Processos Industriais              NOx (t)   3.546360e+06
#                                    SF6 (t)   4.705800e+02
#
# [72 rows x 1 columns]

# %%
gas_por_setor.swaplevel(0, 1).groupby(level = 0).idxmax()
# Out:
#                                                                               Emissão
# Nível 1 - Setor
# Agropecuária                                         (Agropecuária, CO2e (t) GWP-AR5)
# Energia                                                   (Energia, CO2e (t) GWP-AR6)
# Mudança de Uso da Terra e Floresta  (Mudança de Uso da Terra e Floresta, CO2e (t) ...
# Processos Industriais                       (Processos Industriais, CO2e (t) GWP-AR6)
# Resíduos                                                (Resíduos , CO2e (t) GWP-AR5)

# %% [markdown]
# ## 📈 Análise temporal das emissões::

# %%
emissoes_por_ano.groupby('Ano')['Emissão'].sum().plot(figsize=(10,5))
plt.title('Evolução total das emissões ao longo do tempo')
plt.show()

# %% [markdown]
# ### 📌 Insight – Evolução total
#
# Observa-se um crescimento significativo das emissões ao longo do tempo, com aceleração após os anos 1990.
#
# Esse aumento pode estar associado à inclusão de dados sobre uso da terra e expansão das atividades econômicas no país.

# %% [markdown]
#  Nesta etapa, analisamos a evolução das emissões ao longo do tempo, tanto de forma geral quanto separadamente por tipo de gás.
#
# O objetivo é identificar tendências, padrões de crescimento e possíveis mudanças estruturais ao longo dos anos.

# %% [markdown]
# ### 📌 Insight – Pico de emissão
#
# O ano de 2003 apresentou a maior média de emissões no período analisado, indicando um ponto crítico na série histórica.

# %%
top_gases = emissoes_por_ano.groupby('Gás')['Emissão'] \
    .sum() \
    .sort_values(ascending=False) \
    .head(5) \
    .index

emissoes_por_ano[emissoes_por_ano['Gás'].isin(top_gases)] \
    .groupby(['Ano', 'Gás'])['Emissão'] \
    .sum() \
    .unstack() \
    .plot(figsize=(12,6))

plt.title('Evolução dos principais gases')
plt.show()

# %% [markdown]
# ### 📌 Insight – Diferença entre gases
#
# Os principais gases apresentam comportamentos distintos ao longo do tempo, indicando que as fontes de emissão não evoluem de forma uniforme.
#
# Enquanto alguns gases apresentam crescimento contínuo, outros mostram estabilidade ou redução, refletindo mudanças em setores específicos da economia.

# %%
evolucao = emissoes_por_ano.groupby('Ano')['Emissão'].sum()

crescimento = ((evolucao.iloc[-1] - evolucao.iloc[0]) / evolucao.iloc[0]) * 100

print(f'Crescimento total das emissões: {crescimento:.2f}%')
# Out:
# Crescimento total das emissões: 796.71%

# %% [markdown]
# ## 👥 Emissão per capita por estado

# %% [markdown]
# Nesta etapa, calculamos a emissão per capita de gases do efeito estufa por estado.
#
# Essa métrica permite uma análise mais justa, pois considera o tamanho da população, evitando distorções causadas por estados mais populosos.

# %%
emissao_estado = emissoes_por_ano.groupby('Estado')['Emissão'].sum()

# %%
# populacao_estados['POPULAÇÃO'].astype(int)

# %% [markdown]
# ## 🎯 Conclusão Final
#
# A análise das emissões de gases do efeito estufa no Brasil entre 1970 e 2021 revelou que:
#
# - As emissões cresceram significativamente ao longo do tempo
# - O CO₂ equivalente domina a matriz de emissões
# - Entre os gases individuais, o CO₂ é o principal responsável
# - O setor de uso da terra e floresta é o maior emissor
#
# Esses resultados indicam que políticas ambientais devem priorizar:
# - Redução do desmatamento
# - Controle de emissões energéticas
# - Monitoramento de setores críticos
#
# A análise demonstra a importância de dados históricos para apoiar decisões estratégicas e ambientais.

# %% [markdown]
# A análise revelou que:
#
# - As emissões cresceram ao longo do tempo
# - O CO₂ equivalente domina as emissões totais
# - O setor de uso da terra é o principal responsável
# - Existem diferenças relevantes entre os gases ao longo dos anos
#
# Esses resultados indicam que políticas ambientais devem priorizar setores específicos e gases dominantes para maior efetividade.
